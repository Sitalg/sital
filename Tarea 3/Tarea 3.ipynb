# %%
#1. Cargue los datos del archivo CSV 'hipparcos-voidmain.csv' en un nuevo DataFrame. Los archivos se encuentran en la carpeta principal de la Sesión 5.
import pandas as pd
import matplotlib.pyplot as plt
hipp=pd.read_csv('hipparcos-voidmain.csv')
hipp.head()
# Out:
#   Catalog  HIP Proxy        RAhms        DEdms  Vmag  VarFlag r_Vmag  \
# 0       H    1   NaN  00 00 00.22  +01 05 20.4  9.10      NaN      H
# 1       H    2   NaN  00 00 00.91  -19 29 55.8  9.27      NaN      G
# 2       H    3   NaN  00 00 01.20  +38 51 33.4  6.61      NaN      G
# 3       H    4   NaN  00 00 02.01  -51 53 36.8  8.06      NaN      H
# 4       H    5   NaN  00 00 02.39  -40 35 28.4  8.55      NaN      H
#
#       RAdeg      DEdeg AstroRef    Plx    pmRA  pmDE  e_RAdeg  e_DEdeg  e_Plx  \
# 0  0.000912   1.089013      NaN   3.54   -5.20 -1.88     1.32     0.74   1.39
# 1  0.003797 -19.498837        +  21.90  181.21 -0.93     1.28     0.70   3.10
# 2  0.005008  38.859286      NaN   2.81    5.24 -2.91     0.53     0.40   0.63
# 3  0.008382 -51.893546      NaN   7.75   62.85  0.16     0.53     0.59   0.97
# 4  0.009965 -40.591224      NaN   2.87    2.53  9.07     0.64     0.61   1.11
#
#    e_pmRA  e_pmDE  DE:RA  Plx:RA  Plx:DE  pmRA:RA  pmRA:DE  pmRA:Plx  pmDE:RA  \
# 0    1.36    0.81   0.32   -0.07   -0.11    -0.24     0.09     -0.01     0.10
# 1    1.74    0.92   0.12   -0.14   -0.24    -0.29     0.01      0.21    -0.02
# 2    0.57    0.47   0.06    0.09    0.04     0.43    -0.01     -0.06     0.03
# 3    0.65    0.65  -0.22   -0.09   -0.03     0.24     0.20      0.08     0.18
# 4    0.67    0.74   0.10    0.24    0.06     0.26    -0.10      0.20    -0.16
#
#    pmDE:DE  pmDE:Plx  pmDE:pmRA   F1    F2  ---   BTmag  e_BTmag  VTmag  \
# 0    -0.01      0.01       0.34  0.0  0.74    1   9.643    0.020  9.130
# 1    -0.19     -0.28       0.14  2.0  1.45    2  10.519    0.033  9.378
# 2     0.24      0.07       0.21  0.0 -0.45    3   6.576    0.004  6.621
# 3     0.08     -0.31      -0.18  0.0 -1.46    4   8.471    0.007  8.092
# 4    -0.30     -0.19       0.06  0.0 -1.24    5   9.693    0.014  8.656
#
#    e_VTmag m_BTmag    B-V  e_B-V r_B-V   V-I  e_V-I r_V-I CombMag   Hpmag  \
# 0    0.019     NaN  0.482  0.025     T  0.55   0.03     L     NaN  9.2043
# 1    0.021     NaN  0.999  0.002     G  1.04   0.00     I     NaN  9.4017
# 2    0.005     NaN -0.019  0.004     G  0.00   0.00     H     NaN  6.6081
# 3    0.007     NaN  0.370  0.009     T  0.43   0.01     L     NaN  8.1498
# 4    0.010     NaN  0.902  0.013     T  0.90   0.01     L     NaN  8.7077
#
#    e_Hpmag  Hpscat  o_Hpmag m_Hpmag  Hpmax  HPmin  Period HvarType  moreVar  \
# 0   0.0020   0.017     87.0     NaN   9.17   9.24     NaN      NaN      NaN
# 1   0.0017   0.015    120.0     NaN   9.37   9.44     NaN        C      NaN
# 2   0.0007   0.008    127.0     NaN   6.60   6.62     NaN        C      NaN
# 3   0.0011   0.015    201.0     NaN   8.12   8.18     NaN      NaN      NaN
# 4   0.0018   0.019    161.0     NaN   8.68   8.74     NaN      NaN      NaN
#
#   morePhoto        CCDM n_CCDM  Nsys  Ncomp MultFlag Source Qual m_HIP  theta  \
# 0       NaN         NaN    NaN   NaN    1.0      NaN    NaN  NaN   NaN    NaN
# 1       NaN         NaN    NaN   NaN    1.0        O    NaN  NaN   NaN    NaN
# 2       NaN  00000+3852      I   1.0    1.0      NaN    NaN  NaN   NaN    NaN
# 3       NaN         NaN    NaN   NaN    1.0      NaN    NaN  NaN   NaN    NaN
# 4       NaN         NaN    NaN   NaN    1.0      NaN    NaN  NaN   NaN    NaN
#
#    rho  e_rho  dHp  e_dHp Survey Chart Notes        HD         BD         CoD  \
# 0  NaN    NaN  NaN    NaN      S   NaN   NaN  224700.0  B+00 5077         NaN
# 1  NaN    NaN  NaN    NaN    NaN   NaN   NaN  224690.0  B-20 6688         NaN
# 2  NaN    NaN  NaN    NaN      S   NaN   NaN  224699.0  B+38 5108         NaN
# 3  NaN    NaN  NaN    NaN      S   NaN   NaN  224707.0        NaN         NaN
# 4  NaN    NaN  NaN    NaN    NaN   NaN   NaN  224705.0        NaN  C-41 15372
#
#           CPD  (V-I)red SpType r_SpType
# 0         NaN      0.66     F5        S
# 1         NaN      1.04    K3V        4
# 2         NaN      0.00     B9        S
# 3  P-52 12237      0.43    F0V        2
# 4  P-41  9991      0.95  G8III        2

# %%
#2. Muestre las últimas 5 filas del DataFrame.
hipp.tail()
# Out:
#        Catalog     HIP Proxy        RAhms        DEdms  Vmag  VarFlag r_Vmag  \
# 118213       H  118318   NaN  23 59 51.30  +11 40 25.4  6.99      1.0      H
# 118214       H  118319   NaN  23 59 53.74  -22 25 41.4  8.23      NaN      G
# 118215       H  118320   NaN  23 59 54.25  +05 57 23.9  7.59      NaN      H
# 118216       H  118321   NaN  23 59 54.78  -64 22 21.3  9.20      NaN      G
# 118217       H  118322   NaN  23 59 54.91  -65 34 37.5  4.49      NaN      H
#
#              RAdeg      DEdeg AstroRef    Plx    pmRA    pmDE  e_RAdeg  \
# 118213  359.963744  11.673709      NaN   1.92   -2.16    2.09     0.78
# 118214  359.973913 -22.428180      NaN  10.63  148.74   27.53     0.97
# 118215  359.976057   5.956638      NaN   5.00   20.92  -35.26     0.95
# 118216  359.978239 -64.372572      NaN  19.22  216.99  106.46     0.74
# 118217  359.978792 -65.577078      NaN   8.71   48.63  -22.33     0.44
#
#         e_DEdeg  e_Plx  e_pmRA  e_pmDE  DE:RA  Plx:RA  Plx:DE  pmRA:RA  \
# 118213     0.50   0.91    0.88    0.60   0.33   -0.02   -0.09    -0.19
# 118214     0.58   1.17    1.10    0.52   0.04    0.17    0.04    -0.11
# 118215     0.53   1.01    0.89    0.54   0.21    0.00   -0.05    -0.18
# 118216     0.76   1.00    0.84    0.81   0.01   -0.07   -0.24    -0.03
# 118217     0.42   0.57    0.48    0.47   0.03   -0.12   -0.18    -0.17
#
#         pmRA:DE  pmRA:Plx  pmDE:RA  pmDE:DE  pmDE:Plx  pmDE:pmRA   F1    F2  \
# 118213    -0.03      0.21    -0.02    -0.11      0.27       0.49  0.0  2.00
# 118214     0.10      0.17     0.07    -0.31      0.12      -0.05  0.0  1.19
# 118215     0.01     -0.04     0.01    -0.14      0.22       0.27  4.0 -1.12
# 118216     0.15     -0.04     0.15     0.01     -0.14       0.12  0.0  0.05
# 118217     0.02      0.17     0.07    -0.12     -0.08       0.22  0.0 -1.72
#
#            ---   BTmag  e_BTmag  VTmag  e_VTmag m_BTmag    B-V  e_B-V r_B-V  \
# 118213  118318   9.107    0.015  7.186    0.007     NaN  1.595  0.013     T
# 118214  118319   9.019    0.013  8.295    0.011     NaN  0.639  0.015     G
# 118215  118320   8.868    0.013  7.704    0.009     NaN  0.999  0.012     T
# 118216  118321  10.077    0.031  9.318    0.026     NaN  0.698  0.003     G
# 118217  118322   4.396    0.002  4.482    0.002     NaN -0.075  0.011     G
#
#          V-I  e_V-I r_V-I CombMag   Hpmag  e_Hpmag  Hpscat  o_Hpmag m_Hpmag  \
# 118213  1.61   0.01     L     NaN  7.1043   0.0018   0.014     92.0     NaN
# 118214  0.70   0.01     H     NaN  8.3699   0.0014   0.016    118.0     NaN
# 118215  0.98   0.01     L     NaN  7.7604   0.0010   0.010     86.0     NaN
# 118216  0.75   0.00     H     NaN  9.3312   0.0019   0.022    145.0     NaN
# 118217 -0.04   0.02     A     NaN  4.4758   0.0003   0.004    136.0     NaN
#
#         Hpmax  HPmin  Period HvarType  moreVar morePhoto CCDM n_CCDM  Nsys  \
# 118213   7.08   7.12     NaN        M      NaN       NaN  NaN    NaN   NaN
# 118214   8.34   8.39     NaN        C      NaN       NaN  NaN    NaN   NaN
# 118215   7.74   7.77     NaN        C      NaN       NaN  NaN    NaN   NaN
# 118216   9.28   9.36     NaN      NaN      NaN       NaN  NaN    NaN   NaN
# 118217   4.47   4.48     NaN      NaN      NaN       NaN  NaN    NaN   NaN
#
#         Ncomp MultFlag Source Qual m_HIP  theta  rho  e_rho  dHp  e_dHp  \
# 118213    1.0      NaN    NaN  NaN   NaN    NaN  NaN    NaN  NaN    NaN
# 118214    1.0      NaN    NaN  NaN   NaN    NaN  NaN    NaN  NaN    NaN
# 118215    1.0      NaN    NaN  NaN   NaN    NaN  NaN    NaN  NaN    NaN
# 118216    1.0      NaN    NaN  NaN   NaN    NaN  NaN    NaN  NaN    NaN
# 118217    1.0      NaN    NaN  NaN   NaN    NaN  NaN    NaN  NaN    NaN
#
#        Survey Chart Notes        HD         BD         CoD         CPD  \
# 118213      S   NaN   NaN  224673.0  B+10 5018         NaN         NaN
# 118214      S   NaN   NaN  224693.0        NaN  C-23 18108  P-23  8366
# 118215      S   NaN   NaN  224689.0  B+05 5245         NaN         NaN
# 118216    NaN   NaN   NaN  224685.0        NaN  C-65  2958  P-65  4188
# 118217      S   NaN   NaN  224686.0        NaN         NaN  P-66  3819
#
#         (V-I)red SpType r_SpType
# 118213      1.56     K2        S
# 118214      0.70    G2V        4
# 118215      0.98     K0        S
# 118216      0.75    G5V        1
# 118217     -0.04   B9IV        X

# %%
#3. Muestre las primeras 3 columnas del DataFrame.
pd.set_option("display.max.columns",3)

# %%
hipp.head()
# Out:
#   Catalog  ...  r_SpType
# 0       H  ...         S
# 1       H  ...         4
# 2       H  ...         S
# 3       H  ...         2
# 4       H  ...         2
#
# [5 rows x 78 columns]

# %%
#4. A partir del DataFrame original, cree un nuevo DataFrame que contenga las columnas 'HIP', 'RAhms', 'DEdms', 'Vmag', 'Plx', 'SpType', 'B-V'.
pd.set_option("display.max.columns", None)
hipp.head()
# Out:
#   Catalog  HIP Proxy        RAhms        DEdms  Vmag  VarFlag r_Vmag  \
# 0       H    1   NaN  00 00 00.22  +01 05 20.4  9.10      NaN      H
# 1       H    2   NaN  00 00 00.91  -19 29 55.8  9.27      NaN      G
# 2       H    3   NaN  00 00 01.20  +38 51 33.4  6.61      NaN      G
# 3       H    4   NaN  00 00 02.01  -51 53 36.8  8.06      NaN      H
# 4       H    5   NaN  00 00 02.39  -40 35 28.4  8.55      NaN      H
#
#       RAdeg      DEdeg AstroRef    Plx    pmRA  pmDE  e_RAdeg  e_DEdeg  e_Plx  \
# 0  0.000912   1.089013      NaN   3.54   -5.20 -1.88     1.32     0.74   1.39
# 1  0.003797 -19.498837        +  21.90  181.21 -0.93     1.28     0.70   3.10
# 2  0.005008  38.859286      NaN   2.81    5.24 -2.91     0.53     0.40   0.63
# 3  0.008382 -51.893546      NaN   7.75   62.85  0.16     0.53     0.59   0.97
# 4  0.009965 -40.591224      NaN   2.87    2.53  9.07     0.64     0.61   1.11
#
#    e_pmRA  e_pmDE  DE:RA  Plx:RA  Plx:DE  pmRA:RA  pmRA:DE  pmRA:Plx  pmDE:RA  \
# 0    1.36    0.81   0.32   -0.07   -0.11    -0.24     0.09     -0.01     0.10
# 1    1.74    0.92   0.12   -0.14   -0.24    -0.29     0.01      0.21    -0.02
# 2    0.57    0.47   0.06    0.09    0.04     0.43    -0.01     -0.06     0.03
# 3    0.65    0.65  -0.22   -0.09   -0.03     0.24     0.20      0.08     0.18
# 4    0.67    0.74   0.10    0.24    0.06     0.26    -0.10      0.20    -0.16
#
#    pmDE:DE  pmDE:Plx  pmDE:pmRA   F1    F2  ---   BTmag  e_BTmag  VTmag  \
# 0    -0.01      0.01       0.34  0.0  0.74    1   9.643    0.020  9.130
# 1    -0.19     -0.28       0.14  2.0  1.45    2  10.519    0.033  9.378
# 2     0.24      0.07       0.21  0.0 -0.45    3   6.576    0.004  6.621
# 3     0.08     -0.31      -0.18  0.0 -1.46    4   8.471    0.007  8.092
# 4    -0.30     -0.19       0.06  0.0 -1.24    5   9.693    0.014  8.656
#
#    e_VTmag m_BTmag    B-V  e_B-V r_B-V   V-I  e_V-I r_V-I CombMag   Hpmag  \
# 0    0.019     NaN  0.482  0.025     T  0.55   0.03     L     NaN  9.2043
# 1    0.021     NaN  0.999  0.002     G  1.04   0.00     I     NaN  9.4017
# 2    0.005     NaN -0.019  0.004     G  0.00   0.00     H     NaN  6.6081
# 3    0.007     NaN  0.370  0.009     T  0.43   0.01     L     NaN  8.1498
# 4    0.010     NaN  0.902  0.013     T  0.90   0.01     L     NaN  8.7077
#
#    e_Hpmag  Hpscat  o_Hpmag m_Hpmag  Hpmax  HPmin  Period HvarType  moreVar  \
# 0   0.0020   0.017     87.0     NaN   9.17   9.24     NaN      NaN      NaN
# 1   0.0017   0.015    120.0     NaN   9.37   9.44     NaN        C      NaN
# 2   0.0007   0.008    127.0     NaN   6.60   6.62     NaN        C      NaN
# 3   0.0011   0.015    201.0     NaN   8.12   8.18     NaN      NaN      NaN
# 4   0.0018   0.019    161.0     NaN   8.68   8.74     NaN      NaN      NaN
#
#   morePhoto        CCDM n_CCDM  Nsys  Ncomp MultFlag Source Qual m_HIP  theta  \
# 0       NaN         NaN    NaN   NaN    1.0      NaN    NaN  NaN   NaN    NaN
# 1       NaN         NaN    NaN   NaN    1.0        O    NaN  NaN   NaN    NaN
# 2       NaN  00000+3852      I   1.0    1.0      NaN    NaN  NaN   NaN    NaN
# 3       NaN         NaN    NaN   NaN    1.0      NaN    NaN  NaN   NaN    NaN
# 4       NaN         NaN    NaN   NaN    1.0      NaN    NaN  NaN   NaN    NaN
#
#    rho  e_rho  dHp  e_dHp Survey Chart Notes        HD         BD         CoD  \
# 0  NaN    NaN  NaN    NaN      S   NaN   NaN  224700.0  B+00 5077         NaN
# 1  NaN    NaN  NaN    NaN    NaN   NaN   NaN  224690.0  B-20 6688         NaN
# 2  NaN    NaN  NaN    NaN      S   NaN   NaN  224699.0  B+38 5108         NaN
# 3  NaN    NaN  NaN    NaN      S   NaN   NaN  224707.0        NaN         NaN
# 4  NaN    NaN  NaN    NaN    NaN   NaN   NaN  224705.0        NaN  C-41 15372
#
#           CPD  (V-I)red SpType r_SpType
# 0         NaN      0.66     F5        S
# 1         NaN      1.04    K3V        4
# 2         NaN      0.00     B9        S
# 3  P-52 12237      0.43    F0V        2
# 4  P-41  9991      0.95  G8III        2

# %%
filas = hipp.loc[:, ['HIP','RAhms', 'DEdms', 'Vmag', 'Plx', 'B-V']]
filas
# Out:
#            HIP        RAhms        DEdms  Vmag    Plx    B-V
# 0            1  00 00 00.22  +01 05 20.4  9.10   3.54  0.482
# 1            2  00 00 00.91  -19 29 55.8  9.27  21.90  0.999
# 2            3  00 00 01.20  +38 51 33.4  6.61   2.81 -0.019
# 3            4  00 00 02.01  -51 53 36.8  8.06   7.75  0.370
# 4            5  00 00 02.39  -40 35 28.4  8.55   2.87  0.902
# ...        ...          ...          ...   ...    ...    ...
# 118213  118318  23 59 51.30  +11 40 25.4  6.99   1.92  1.595
# 118214  118319  23 59 53.74  -22 25 41.4  8.23  10.63  0.639
# 118215  118320  23 59 54.25  +05 57 23.9  7.59   5.00  0.999
# 118216  118321  23 59 54.78  -64 22 21.3  9.20  19.22  0.698
# 118217  118322  23 59 54.91  -65 34 37.5  4.49   8.71 -0.075
#
# [118218 rows x 6 columns]

# %%
#5. Cambie el nombre de la columna 'B-V' a 'BV'.
fila2=filas.rename(columns={'B-V':'BV'})
fila2
# Out:
#            HIP        RAhms        DEdms  Vmag    Plx     BV
# 0            1  00 00 00.22  +01 05 20.4  9.10   3.54  0.482
# 1            2  00 00 00.91  -19 29 55.8  9.27  21.90  0.999
# 2            3  00 00 01.20  +38 51 33.4  6.61   2.81 -0.019
# 3            4  00 00 02.01  -51 53 36.8  8.06   7.75  0.370
# 4            5  00 00 02.39  -40 35 28.4  8.55   2.87  0.902
# ...        ...          ...          ...   ...    ...    ...
# 118213  118318  23 59 51.30  +11 40 25.4  6.99   1.92  1.595
# 118214  118319  23 59 53.74  -22 25 41.4  8.23  10.63  0.639
# 118215  118320  23 59 54.25  +05 57 23.9  7.59   5.00  0.999
# 118216  118321  23 59 54.78  -64 22 21.3  9.20  19.22  0.698
# 118217  118322  23 59 54.91  -65 34 37.5  4.49   8.71 -0.075
#
# [118218 rows x 6 columns]

# %%
#6. ¿Cuál es el valor máximo de las magnitudes aparentes en la columna 'Vmag'? ¿Cuál es el valor mínimo?
vmag = hipp.Vmag
vmag
# Out:
# 0         9.10
# 1         9.27
# 2         6.61
# 3         8.06
# 4         8.55
#           ...
# 118213    6.99
# 118214    8.23
# 118215    7.59
# 118216    9.20
# 118217    4.49
# Name: Vmag, Length: 118218, dtype: float64

# %%
vmag = vmag.to_frame()

# %%
print("El valor máximo de Vmag es:",vmag.max())
# Out:
# El valor máximo de Vmag es: Vmag    14.08
# dtype: float64

# %%
print("El valor máximo de Vmag es:",vmag.min())
# Out:
# El valor máximo de Vmag es: Vmag   -1.44
# dtype: float64

# %%
#7. Muestre la columna 'Vmag'en orden ascendente. Ayuda: puede utilizar '.sort_values()' y elegir la columna correcta.
vmag.sort_values(by=['Vmag'])
# Out:
#          Vmag
# 32324   -1.44
# 30416   -0.62
# 69609   -0.05
# 71618   -0.01
# 91179    0.03
# ...       ...
# 15547   13.63
# 36618   13.64
# 105199  13.78
# 70015   14.08
# 25189     NaN
#
# [118218 rows x 1 columns]

# %%
#8. ¿Cuántas estrellas tienen una magnitud aparente superior a 10.0? Seleccione solo estas estrellas en el DataFrame y muéstrelas. Guarde estos datos en un nuevo .csv llamado 'estrellas_filtro.csv'.
vmag[vmag.Vmag>10.0]
# Out:
#          Vmag
# 5       12.31
# 16      11.71
# 17      11.03
# 36      10.44
# 40      10.61
# ...       ...
# 118135  11.41
# 118169  10.11
# 118200  11.94
# 118207  11.85
# 118212  10.01
#
# [10214 rows x 1 columns]

# %%
print("Este DataFrame tiene", vmag[vmag.Vmag>10.0].count(), "estrellas con magnitud aparente superior a 10.0")
# Out:
# Este DataFrame tiene Vmag    10214
# dtype: int64 estrellas con magnitud aparente superior a 10.0

# %%
vmag.to_csv('estrellas_filtro.csv')

# %%
#9. ¿Cuántas estrellas tienen un índice B-V entre 0.3 y 0.6? Muestre estas estrellas y cuente su total. Grafique esta porción de las estrellas en un histograma. Ajuste los rangos y bins como sea necesario.
fila2
# Out:
#            HIP     MagAb   Distancia        RAhms        DEdms  Vmag    Plx  \
# 0            1  1.845016  282.485876  00 00 00.22  +01 05 20.4  9.10   3.54
# 1            2  5.972221   45.662100  00 00 00.91  -19 29 55.8  9.27  21.90
# 2            3 -1.146468  355.871886  00 00 01.20  +38 51 33.4  6.61   2.81
# 3            4  2.506509  129.032258  00 00 02.01  -51 53 36.8  8.06   7.75
# 4            5  0.839409  348.432056  00 00 02.39  -40 35 28.4  8.55   2.87
# ...        ...       ...         ...          ...          ...   ...    ...
# 118213  118318 -1.593494  520.833333  23 59 51.30  +11 40 25.4  6.99   1.92
# 118214  118319  3.362666   94.073377  23 59 53.74  -22 25 41.4  8.23  10.63
# 118215  118320  1.084850  200.000000  23 59 54.25  +05 57 23.9  7.59   5.00
# 118216  118321  5.618767   52.029136  23 59 54.78  -64 22 21.3  9.20  19.22
# 118217  118322 -0.809909  114.810563  23 59 54.91  -65 34 37.5  4.49   8.71
#
#            BV
# 0       0.482
# 1       0.999
# 2      -0.019
# 3       0.370
# 4       0.902
# ...       ...
# 118213  1.595
# 118214  0.639
# 118215  0.999
# 118216  0.698
# 118217 -0.075
#
# [118218 rows x 8 columns]

# %%
Bv = fila2.BV
Bv
# Out:
# 0         0.482
# 1         0.999
# 2        -0.019
# 3         0.370
# 4         0.902
#           ...
# 118213    1.595
# 118214    0.639
# 118215    0.999
# 118216    0.698
# 118217   -0.075
# Name: BV, Length: 118218, dtype: float64

# %%
Bv = Bv.to_frame()

# %%
Bv.min()
# Out:
# BV   -0.4
# dtype: float64

# %%
Bv.max()
# Out:
# BV    5.46
# dtype: float64

# %%
[Bv[Bv.BV>0.3] and Bv[Bv.BV<0.6]]
# Out:
#   File "<ipython-input-367-885e514e278f>", line 1
#     def [Bv[Bv.BV>0.3] and Bv[Bv.BV<0.6]]
#         ^
# SyntaxError: invalid syntax

# %%
[Bv[Bv.BV>0.3] and Bv[Bv.BV<0.6]].count()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-368-66d37f4d47ed> in <module>
# ----> 1 [Bv[Bv.BV>0.3] and Bv[Bv.BV<0.6]].count()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
plt.hist(Bv, range=[0.2,0.7], bins=100)
# Out:
# (array([485., 300., 225., 294., 311., 248., 371., 215., 318., 273., 260.,
#         272., 346., 239., 273., 292., 398., 224., 341., 279., 333., 342.,
#         368., 294., 368., 288., 376., 317., 386., 354., 399., 339., 439.,
#         339., 393., 418., 403., 470., 476., 497., 693., 547., 551., 464.,
#         524., 483., 565., 553., 597., 615., 615., 644., 654., 615., 632.,
#         593., 681., 617., 646., 636., 789., 636., 657., 590., 685., 609.,
#         612., 531., 629., 555., 572., 521., 633., 578., 618., 455., 580.,
#         465., 515., 400., 598., 402., 449., 422., 427., 380., 464., 405.,
#         434., 359., 410., 343., 400., 307., 370., 280., 311., 305., 268.,
#         449.]),
#  array([0.2  , 0.205, 0.21 , 0.215, 0.22 , 0.225, 0.23 , 0.235, 0.24 ,
#         0.245, 0.25 , 0.255, 0.26 , 0.265, 0.27 , 0.275, 0.28 , 0.285,
#         0.29 , 0.295, 0.3  , 0.305, 0.31 , 0.315, 0.32 , 0.325, 0.33 ,
#         0.335, 0.34 , 0.345, 0.35 , 0.355, 0.36 , 0.365, 0.37 , 0.375,
#         0.38 , 0.385, 0.39 , 0.395, 0.4  , 0.405, 0.41 , 0.415, 0.42 ,
#         0.425, 0.43 , 0.435, 0.44 , 0.445, 0.45 , 0.455, 0.46 , 0.465,
#         0.47 , 0.475, 0.48 , 0.485, 0.49 , 0.495, 0.5  , 0.505, 0.51 ,
#         0.515, 0.52 , 0.525, 0.53 , 0.535, 0.54 , 0.545, 0.55 , 0.555,
#         0.56 , 0.565, 0.57 , 0.575, 0.58 , 0.585, 0.59 , 0.595, 0.6  ,
#         0.605, 0.61 , 0.615, 0.62 , 0.625, 0.63 , 0.635, 0.64 , 0.645,
#         0.65 , 0.655, 0.66 , 0.665, 0.67 , 0.675, 0.68 , 0.685, 0.69 ,
#         0.695, 0.7  ]),
#  <BarContainer object of 100 artists>)

# %%
#10. Replique el diagrama H-R realizado en la lección 6. Necesitará calcular la Magnitud Absoluta como se hizo en la Sesión 6.
import math
import numpy

# %%
fila2.insert(loc=1, column='Distancia', value='')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-304-38029a400d9a> in <module>
# ----> 1 fila2.insert(loc=1, column='Distancia', value='')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert Distancia, already exists

# %%
fila2.head()
# Out:
#    HIP     MagAb   Distancia        RAhms        DEdms  Vmag    Plx     BV
# 0    1  1.845016  282.485876  00 00 00.22  +01 05 20.4  9.10   3.54  0.482
# 1    2  5.972221   45.662100  00 00 00.91  -19 29 55.8  9.27  21.90  0.999
# 2    3 -1.146468  355.871886  00 00 01.20  +38 51 33.4  6.61   2.81 -0.019
# 3    4  2.506509  129.032258  00 00 02.01  -51 53 36.8  8.06   7.75  0.370
# 4    5  0.839409  348.432056  00 00 02.39  -40 35 28.4  8.55   2.87  0.902

# %%
fila2['Distancia'] = (1/(fila2['Plx']*10**-3))
fila2
# Out:
#            HIP     MagAb   Distancia        RAhms        DEdms  Vmag    Plx  \
# 0            1  1.845016  282.485876  00 00 00.22  +01 05 20.4  9.10   3.54
# 1            2  5.972221   45.662100  00 00 00.91  -19 29 55.8  9.27  21.90
# 2            3 -1.146468  355.871886  00 00 01.20  +38 51 33.4  6.61   2.81
# 3            4  2.506509  129.032258  00 00 02.01  -51 53 36.8  8.06   7.75
# 4            5  0.839409  348.432056  00 00 02.39  -40 35 28.4  8.55   2.87
# ...        ...       ...         ...          ...          ...   ...    ...
# 118213  118318 -1.593494  520.833333  23 59 51.30  +11 40 25.4  6.99   1.92
# 118214  118319  3.362666   94.073377  23 59 53.74  -22 25 41.4  8.23  10.63
# 118215  118320  1.084850  200.000000  23 59 54.25  +05 57 23.9  7.59   5.00
# 118216  118321  5.618767   52.029136  23 59 54.78  -64 22 21.3  9.20  19.22
# 118217  118322 -0.809909  114.810563  23 59 54.91  -65 34 37.5  4.49   8.71
#
#            BV
# 0       0.482
# 1       0.999
# 2      -0.019
# 3       0.370
# 4       0.902
# ...       ...
# 118213  1.595
# 118214  0.639
# 118215  0.999
# 118216  0.698
# 118217 -0.075
#
# [118218 rows x 8 columns]

# %%
fila2.insert(loc=1, column='MagAb', value='')
fila2.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-307-cba544fe7f9d> in <module>
# ----> 1 fila2.insert(loc=1, column='MagAb', value='')
#       2 fila2.head()
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
#    1176             # Should this be a different kind of error??
# -> 1177             raise ValueError(f"cannot insert {item}, already exists")
#    1178
#    1179         if not isinstance(loc, int):
#
# ValueError: cannot insert MagAb, already exists

# %%
fila2['MagAb']=(fila2['Vmag']-5*numpy.log10(fila2['Distancia'])+5)
fila2
# Out:
# C:\Users\Usuario\anaconda3\lib\site-packages\pandas\core\series.py:726: RuntimeWarning: invalid value encountered in log10
#   result = getattr(ufunc, method)(*inputs, **kwargs)
#            HIP     MagAb   Distancia        RAhms        DEdms  Vmag    Plx  \
# 0            1  1.845016  282.485876  00 00 00.22  +01 05 20.4  9.10   3.54
# 1            2  5.972221   45.662100  00 00 00.91  -19 29 55.8  9.27  21.90
# 2            3 -1.146468  355.871886  00 00 01.20  +38 51 33.4  6.61   2.81
# 3            4  2.506509  129.032258  00 00 02.01  -51 53 36.8  8.06   7.75
# 4            5  0.839409  348.432056  00 00 02.39  -40 35 28.4  8.55   2.87
# ...        ...       ...         ...          ...          ...   ...    ...
# 118213  118318 -1.593494  520.833333  23 59 51.30  +11 40 25.4  6.99   1.92
# 118214  118319  3.362666   94.073377  23 59 53.74  -22 25 41.4  8.23  10.63
# 118215  118320  1.084850  200.000000  23 59 54.25  +05 57 23.9  7.59   5.00
# 118216  118321  5.618767   52.029136  23 59 54.78  -64 22 21.3  9.20  19.22
# 118217  118322 -0.809909  114.810563  23 59 54.91  -65 34 37.5  4.49   8.71
#
#            BV
# 0       0.482
# 1       0.999
# 2      -0.019
# 3       0.370
# 4       0.902
# ...       ...
# 118213  1.595
# 118214  0.639
# 118215  0.999
# 118216  0.698
# 118217 -0.075
#
# [118218 rows x 8 columns]

# %%
9.10-5*numpy.log10(282.485876)+5
# Out:
# 1.8450163078706066

# %%
fila2.to_csv('magnitudes.csv')

# %%
fig, ax = plt.subplots(figsize=(10,12))

ax.set_xlim(-0.5, 2.5)
ax.set_ylim(15, -10)
ax.grid()
ax.set_title('H-R Diagram - Hipparcos Catalog')

ax.title.set_fontsize(20)
ax.set_xlabel('Índice de color BV')
ax.set_ylabel('Magnitud absoluta')
plt.scatter(fila2['BV'], fila2['MagAb'], s=1)

# %%
#11. Guarde el diagrama H-R como una imagen en formato PNG utilizando la función de matplotlib 'plt.savefig('hr.png')'

fig, ax = plt.subplots(figsize=(10,12))

ax.set_xlim(-0.5, 2.5)
ax.set_ylim(15, -10)
ax.grid()
ax.set_title('H-R Diagram - Hipparcos Catalog')

ax.title.set_fontsize(20)
ax.set_xlabel('Índice de color BV')
ax.set_ylabel('Magnitud absoluta')
plt.scatter(fila2['BV'], fila2['MagAb'], s=1)
plt.savefig('H-R Diagram - Hipparcos Catalog.png')
